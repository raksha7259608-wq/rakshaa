# %% [markdown]
# <a href="https://colab.research.google.com/github/raksha7259608-wq/rakshaa/blob/main/experiment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Max = lambda a, b : a if(a>b) else b
print (Max(4,5))
x=lambda a:a+1
print(x(5))
x=lambda a,b,c:a+b+c
print(x(5,6,2))
def add4(x):
  return x+4
list1=[4,5,7,8,8,]
list2=list(map(add4,list1))
print(list2)
def start_with_A(s):
  return s[0]=="A"
fruit=["Apple","banana","pear","apricort","orange"]
map_object=map(start_with_A,fruit)
print(list(map_object))
def oddeven(x):
 if x%2 == 0:
  return True
 else:
  return False
listl = [4,5,6,7,8,9]
evenlist = list(filter(oddeven,listl))
print(evenlist)
def starts_with_A(s):
 return s[0]=="A"
fruit=["Apple","banana", "pear","Apricot","orange"]
filter_object=filter(starts_with_A,fruit)
print(list(filter_object))
from functools import reduce
def sum(x,y):
 return x+y
list1 = [6,7,8,9]
S= reduce(sum,listl)
print(S)
# Out:
# 5
# 6
# 13
# [8, 9, 11, 12, 12]
# [True, False, False, False, False]
# [4, 6, 8]
# ['Apple', 'Apricot']
# 39
